# %% [markdown]
# <a href="https://colab.research.google.com/github/Swikruti23/Lab-1/blob/main/UGMR_2023_Module_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-05-11 22:57:23--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   210MB/s    in 0.3s
#
# 2024-05-11 22:57:25 (210 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 1335    1412.7054v3  This paper presents experiments extending the ...    cs
# 9632    1206.6679v6  We propose a general algorithm for approximati...  stat
# 21906  1502.02843v3  To scale Gaussian processes (GPs) to large dat...  stat
# 37345  1704.01889v1  Implicit feedback is the simplest form of user...    cs
# 27863  1704.07490v1  Aiming to reduce pollutant emissions, bicycles...    cs
# ...             ...                                                ...   ...
# 11167   1411.2305v1  In real world industrial applications of topic...    cs
# 13212   1308.4338v1  This paper presents two approaches for filter ...    cs
# 12991   1104.4605v1  Modern data acquisition routinely produces mas...  stat
# 11816  1702.02982v1  The seminal paper of Caponnetto and de Vito (2...  stat
# 21568   1102.1204v2  This paper treats the problem of screening for...  stat
#
#                                                    title  year  \
# 1335           Attention for Fine-Grained Categorization  2014
# 9632   Fixed-Form Variational Posterior Approximation...  2012
# 21906                     Distributed Gaussian Processes  2015
# 37345  Conformative Filtering for Implicit Feedback Data  2017
# 27863  A Context Aware and Video-Based Risk Descripto...  2017
# ...                                                  ...   ...
# 11167      Model-Parallel Inference for Big Topic Models  2014
# 13212  SAR Image Despeckling Algorithms using Stochas...  2013
# 12991                       Compressive Network Analysis  2011
# 11816   Fixing an error in Caponnetto and de Vito (2007)  2017
# 21568                  Large Scale Correlation Screening  2011
#
#                                                 keywords
# 1335   [experiments, extending, recurrent, attention,...
# 9632   [algorithm, approximating, nonstandard, poster...
# 21906  [processes, introduce, committee, practical, d...
# 37345  [recommendation, independent, circumvent, assu...
# 27863  [pollutant, emissions, regaining, popularity, ...
# ...                                                  ...
# 11167  [industrial, applications, conceptual, dimensi...
# 13212  [approaches, stochastic, distances, intensity,...
# 12991  [acquisition, routinely, disconnected, classic...
# 11816  [caponnetto, regression, effective, dimensiona...
# 21568  [screening, variables, correlations, dimension...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 1335     [experiments, extending, recurrent, attention,...
# 9632     [algorithm, approximating, nonstandard, poster...
# 21906    [processes, introduce, committee, practical, d...
# 37345    [recommendation, independent, circumvent, assu...
# 27863    [pollutant, emissions, regaining, popularity, ...
#                                ...
# 38029    [exponential, publication, researchers, litera...
# 21679    [component, including, estimation, constructio...
# 13150    [clustered, oracleexpert, interactively, clust...
# 9908     [computerized, instructor, computerized, unsup...
# 4162     [necessary, similarity, different, fundamental...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8806 words.
# Out of those 4534 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="682bfde9-d8ec-4a3d-86a0-7cee3f3dbd2d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("682bfde9-d8ec-4a3d-86a0-7cee3f3dbd2d")) {                    Plotly.newPlot(                        "682bfde9-d8ec-4a3d-86a0-7cee3f3dbd2d",                        [{"x":["pipelines","environments","resolution","sequential","experiments","moderately","categorization","constrained","extending","recognition","advantage","components","inexpensive","supervision","recurrent","classification","engineered","specifically","information","attention","googlenet","detection","structure","substitute","discriminative","discriminate","arbitrarily","approximation","variational","minimizes","algorithm","divergence","stochastic","regression","nonstandard","approximating","approximate","exponential","posterior","illustrate","proportionality","distributions","intractable","distribution","heterogeneous","introduce","practical","subsequently","efficient","computing","recursively","conceptually","parameters","footprint","sufficient","independent","distribute","parallelisation","distributed","recombine","straightforward","computations","committee","processes","infrastructures","computational","resources","approximations","inference","filtering","motivation","different","baselines","memberships","hierarchical","performance","recommendations","recommendation","irrelevant","addressing","circumvent","regarding","assumptions","improvement","popularity","monitoring","emissions","sequences","techniques","decreasing","specially","according","improvements","expertise","smartphone","situation","descriptor","framework","additionally","automatically","including","considering","fatalities","promising","performed","attaining","perspective","formulating","operators","underlying","disadvantage","extension","tabulated","principal","redundant","derivations","effectively","resolutions","effective","distinctive","recognized","establish","implemented","demonstrate","transferring","experimentation","technique","accelerating","instantaneously","specifications","approaches","significantly","mechanism","accelerate","represented","preserving","transformations","workflows","knowledge","inception","accelerates","individual","utilizing","unrealistic","complexity","demographic","variations","investigate","robustness","functions","unconstrained","description","exploiting","illumination","approached","expression","variation","computation","increases","effectiveness","alignment","parameter","biometrics","applications","challenging","misalignment","photometric","recognizing","classifier","stylistic","simulations","currently","therefore","differences","operation","processed","limitations","processing","implementation","expressive","attentional","describes","performances","distortion","collisions","simulation","volumetric","specified","animation","combination","simulated","seamlessly","unprecedented","representation","geometric","animations","potential","decompositions","considers","generation"],"y":[15,85,137,68,658,2,22,58,26,384,88,99,5,68,154,507,12,179,731,165,11,349,332,5,101,16,14,108,58,23,794,26,128,105,1,16,101,41,44,62,1,118,24,222,38,346,149,26,376,114,11,12,242,9,73,118,5,0,97,1,13,36,4,118,2,281,62,29,215,65,22,758,64,1,103,892,23,37,19,23,7,41,65,154,24,43,4,91,388,10,14,102,112,11,6,36,42,506,62,188,277,75,2,113,140,3,77,6,57,119,4,73,1,26,25,5,109,14,274,8,24,51,110,568,14,17,265,19,4,12,442,282,88,19,78,47,42,2,341,13,2,111,45,6,248,6,91,137,99,205,35,64,66,37,6,53,59,159,53,228,51,129,11,398,301,3,12,34,154,3,56,46,137,53,37,36,54,269,121,31,8,103,37,19,5,76,12,37,6,134,65,8,9,344,72,2,155,10,47,152],"type":"bar"},{"x":["pipelines","environments","resolution","sequential","ex ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4534,), (4534, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7975

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Pushing</span> <span style=''>the</span> <span style=''>Limits</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Paraphrastic</span> <span style=''>Sentence</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Embeddings</span> <span style=''>with</span> <span style=''>Millions</span> <span style=''>of</span> <span style=''>Machine</span> <span style='background-color:rgba(0, 255, 0, 0.7692307692307693);'>Translations</span> <br/><br/><span style=''>We</span> <span style=''>extend</span> <span style=''>the</span> <span style=''>work</span> <span style=''>of</span> <span style=''>Wieting</span> <span style=''>et</span> <span style=''>al</span> <span style=''>(2017)</span> <span style=''>back</span> <span style='background-color:rgba(0, 255, 0, 0.7647058823529411);'>translating</span> <span style=''>a</span> <span style=''>large</span> <span style=''>parallel</span> <span style=''>corpus</span> <span style=''>to</span> <span style=''>produce</span> <span style=''>a</span> <span style=''>dataset</span> <span style=''>of</span> <span style=''>more</span> <span style=''>than</span> <span style=''>51</span> <span style=''>million</span> <span style=''>English</span> <span style=''>English</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>sentential</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>paraphrase</span> <span style=''>pairs</span> <span style=''>in</span> <span style=''>a</span> <span style=''>dataset</span> <span style=''>we</span> <span style=''>call</span> <span style=''>ParaNMT</span> <span style=''>50M</span> <span style=''>We</span> <span style=''>find</span> <span style=''>this</span> <span style=''>corpus</span> <span style=''>to</span> <span style=''>be</span> <span style=''>cover</span> <span style=''>many</span> <span style=''>domains</span> <span style=''>and</span> <span style=''>styles</span> <span style=''>of</span> <span style=''>text</span> <span style=''>in</span> <span style=''>addition</span> <span style=''>to</span> <span style=''>being</span> <span style=''>rich</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>paraphrases</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3046471600688468);'>different</span> <span style=''>sentence</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>and</span> <span style=''>we</span> <span style=''>release</span> <span style=''>it</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3050847457627119);'>community</span> <span style=''>To</span> <span style=''>show</span> <span style=''>its</span> <span style=''>utility</span> <span style=''>we</span> <span style=''>use</span> <span style=''>it</span> <span style=''>to</span> <span style=''>train</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>paraphrastic</span> <span style=''>sentence</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>embeddings</span> <span style=''>using</span> <span style=''>only</span> <span style=''>minor</span> <span style=''>changes</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>of</span> <span style=''>Wieting</span> <span style=''>et</span> <span style=''>al</span> <span style=''>(2016b)</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resulting</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>embeddings</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>outperform</span> <span style=''>all</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>supervised</span> <span style=''>systems</span> <span style=''>on</span> <span style=''>every</span> <span style=''>SemEval</span> <span style=''>semantic</span> <span style=''>textual</span> <span style='background-color:rgba(0, 255, 0, 0.3 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Stochastic</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Monotonic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Activation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Functions</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>Laplace</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>that</span> <span style=''>creates</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>unit</span> <span style=''>from</span> <span style=''>any</span> <span style=''>smooth</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>monotonic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>activation</span> <span style=''>function</span> <span style=''>using</span> <span style=''>only</span> <span style=''>Gaussian</span> <span style=''>noise</span> <span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigates</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>application</span> <span style=''>of</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>in</span> <span style=''>training</span> <span style=''>a</span> <span style=''>family</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Restricted</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Boltzmann</span> <span style=''>Machines</span> <span style=''>(RBM)</span> <span style=''>that</span> <span style=''>are</span> <span style=''>closely</span> <span style=''>linked</span> <span style=''>to</span> <span style=''>Bregman</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>divergences</span> <span style=''>This</span> <span style=''>family</span> <span style=''>that</span> <span style=''>we</span> <span style=''>call</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exponential</span> <span style=''>family</span> <span style=''>RBM</span> <span style=''>(Exp</span> <span style=''>RBM)</span> <span style=''>is</span> <span style=''>a</span> <span style=''>subset</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exponential</span> <span style=''>family</span> <span style=''>Harmoniums</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expresses</span> <span style=''>family</span> <span style=''>members</span> <span style=''>through</span> <span style=''>a</span> <span style=''>choice</span> <span style=''>of</span> <span style=''>smooth</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>monotonic</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>linearity</span> <span style=''>for</span> <span style=''>each</span> <span style=''>neuron</span> <span style=''>Using</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>contrastive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>divergence</span> <span style=''>along</span> <span style=''>with</span> <span style=''>our</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>Exp</span> <span style=''>RBM</span> <span style=''>can</span> <span style=''>learn</span> <span style=''>useful</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representations</span> <span style=''>using</span> <span style=''>novel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> < ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Identifying</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Conditional</span> <span style=''>Causal</span> <span style=''>Effects</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>concerns</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3125);'>assessment</span> <span style=''>of</span> <span style=''>the</span> <span style=''>effects</span> <span style=''>of</span> <span style=''>actions</span> <span style=''>from</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3535353535353534);'>combination</span> <span style=''>of</span> <span style=''>nonexperimental</span> <span style=''>data</span> <span style=''>and</span> <span style=''>causal</span> <span style='background-color:rgba(255, 0, 0, 0.30107526881720426);'>assumptions</span> <span style=''>encoded</span> <span style=''>in</span> <span style=''>the</span> <span style=''>form</span> <span style=''>of</span> <span style=''>a</span> <span style=''>directed</span> <span style=''>acyclic</span> <span style=''>graph</span> <span style=''>in</span> <span style=''>which</span> <span style=''>some</span> <span style='background-color:rgba(255, 0, 0, 0.4075949367088609);'>variables</span> <span style=''>are</span> <span style=''>presumed</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.6666666666666666);'>unobserved</span> <span style=''>We</span> <span style=''>provide</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>procedure</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>systematically</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identifies</span> <span style=''>cause</span> <span style=''>effects</span> <span style=''>between</span> <span style=''>two</span> <span style=''>sets</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.4075949367088609);'>variables</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditioned</span> <span style=''>on</span> <span style=''>some</span> <span style=''>other</span> <span style='background-color:rgba(255, 0, 0, 0.4075949367088609);'>variables</span> <span style=''>in</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>polynomial</span> <span style=''>in</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.4075949367088609);'>variables</span> <span style=''>in</span> <span style=''>the</span> <span style=''>graph</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identifiable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditional</span> <span style=''>causal</span> <span style=''>effects</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expressed</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>the</span> <span style=''>observed</span> <span style=''>joint</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>GPatt</span> <span style=''>Fast</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Multidimensional</span> <span style=''>Pattern</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Extrapolation</span> <span style=''>with</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Processes</span> <br/><br/><span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>typically</span> <span style=''>used</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>smoothing</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpolation</span> <span style=''>on</span> <span style=''>small</span> <span style=''>datasets</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>new</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>GPatt</span> <span style=''>enabling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>automatic</span> <span style=''>pattern</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extrapolation</span> <span style=''>with</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>on</span> <span style=''>large</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>multidimensional</span> <span style=''>datasets</span> <span style=''>GPatt</span> <span style=''>unifies</span> <span style=''>and</span> <span style=''>extends</span> <span style=''>highly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expressive</span> <span style=''>kernels</span> <span style=''>and</span> <span style=''>fast</span> <span style=''>exact</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>Without</span> <span style=''>human</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intervention</span> <span style=''>no</span> <span style=''>hand</span> <span style=''>crafting</span> <span style=''>of</span> <span style=''>kernel</span> <span style=''>features</span> <span style=''>and</span> <span style=''>no</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sophisticated</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>initialisation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedures</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>GPatt</span> <span style=''>can</span> <span style=''>solve</span> <span style=''>large</span> <span style=''>scale</span> <span style=''>pattern</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extrapolation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inpainting</span> <span style=''>and</span> <span style=''>kernel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discovery</span> <span style=''>problems</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>including</span> <span style=''>a</span> <span style=''>problem</span> <span style=''>with</span> <span style=''>383400</span> <span style=''>training</span> <span style=''>points</span> <span style=''>We</span> <span style=''>find</span> <span style=''>that</span> <span style=''>GPatt</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significantly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>outperforms</span> <span style=''>popular</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>alternative</span> <span style=''>scalable</span> <span style=''>Gaussian</span> <span style=''>process</span> <span sty ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.08686365254538982)
# 	automatic (0.07404770380918477)
# 	representation (0.12246351014595942)
# 	challenging (0.10715557137771449)
# 	segmentation (0.0704877180491278)
# 	different (0.2698469206123176)
# 	detection (0.1242435030259879)
# 	information (0.26023495906016375)
# 	convolutional (0.12780348878604486)
# 	recognition (0.13670345318618726)
#
# Some Statistics words are:
# 	theoretical (0.15017579105976897)
# 	stochastic (0.13460572576594676)
# 	variables (0.13962832747363135)
# 	statistical (0.15419387242591662)
# 	estimation (0.17327975891511804)
# 	distribution (0.19236564540431944)
# 	algorithm (0.3997990959316926)
# 	dimensional (0.18834756403817177)
# 	inference (0.2074334505273732)
# 	regression (0.1928679055750879)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="dac895e1-f96a-40f0-941d-f5dd74164397" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dac895e1-f96a-40f0-941d-f5dd74164397")) {                    Plotly.newPlot(                        "dac895e1-f96a-40f0-941d-f5dd74164397",                        [{"x":["pipelines","environments","resolution","sequential","experiments","moderately","categorization","constrained","extending","recognition","advantage","components","inexpensive","supervision","recurrent","classification","engineered","specifically","information","attention","googlenet","detection","structure","substitute","discriminative","discriminate","arbitrarily","approximation","variational","minimizes","algorithm","divergence","stochastic","regression","nonstandard","approximating","approximate","exponential","posterior","illustrate","proportionality","distributions","intractable","distribution","heterogeneous","introduce","practical","subsequently","efficient","computing","recursively","conceptually","parameters","footprint","sufficient","independent","distribute","parallelisation","distributed","recombine","straightforward","computations","committee","processes","infrastructures","computational","resources","approximations","inference","filtering","motivation","different","baselines","memberships","hierarchical","performance","recommendations","recommendation","irrelevant","addressing","circumvent","regarding","assumptions","improvement","popularity","monitoring","emissions","sequences","techniques","decreasing","specially","according","improvements","expertise","smartphone","situation","descriptor","framework","additionally","automatically","including","considering","fatalities","promising","performed","attaining","perspective","formulating","operators","underlying","disadvantage","extension","tabulated","principal","redundant","derivations","effectively","resolutions","effective","distinctive","recognized","establish","implemented","demonstrate","transferring","experimentation","technique","accelerating","instantaneously","specifications","approaches","significantly","mechanism","accelerate","represented","preserving","transformations","workflows","knowledge","inception","accelerates","individual","utilizing","unrealistic","complexity","demographic","variations","investigate","robustness","functions","unconstrained","description","exploiting","illumination","approached","expression","variation","computation","increases","effectiveness","alignment","parameter","biometrics","applications","challenging","misalignment","photometric","recognizing","classifier","stylistic","simulations","currently","therefore","differences","operation","processed","limitations","processing","implementation","expressive","attentional","describes","performances","distortion","collisions","simulation","volumetric","specified","animation","combination","simulated","seamlessly","unprecedented","representation","geometric","animations","potential","decompositions","considers","generation","assumption","incoherent","observations","particularly","reassembled","platforms","optimized","collaborative","objective","recommender","sensitive","predictions","unfairness","historical","objectives","insufficiency","synthetic","discrimination","informative","microblogging","allocation","collections","increasing","dirichlet","generated","scalability","interpretation","documents","incorporates","recognize","competitive","efficiency","algorithms","application","architectures","previously","resulting","delivering","transcription","languages","benchmarked","consideration","limitation","denoising","equivalent","undersampled","similarity","linearity","experimental","reconstruction","propagation","annotation", ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	parallelisation
# 	stratification
# 	characterizations
# 	approachability
# 	subdomains
# 	inhibited
# 	contracting
# 	discriminable
# 	rectifier
# 	changepoint
# 	nonparanormal
# 	semiparametric
# 	stationarities
# 	compensating
# 	underlies
# 	covariates
# 	advocated
# 	robustification
# 	robustify
# 	thermodynamics
# Some words which never appear in Statistics papers:
# 	googlenet
# 	smartphone
# 	fatalities
# 	specifications
# 	illumination
# 	misalignment
# 	photometric
# 	stylistic
# 	collisions
# 	animation
# 	animations
# 	reassembled
# 	microblogging
# 	grammatical
# 	warehouses
# 	propositional
# 	sharpening
# 	reflection
# 	vocabularies
# 	attributable

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.065228052967141e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7416666666666667
